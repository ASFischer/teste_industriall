# %%
# %store -r eda_df
import pandas as pd

# %%
eda_df.head()
# Out:
#          00          01         02          03           04          05  \
# 0  4.548754   90.886874  58.698896   89.301134  1011.733181   97.284889
# 1  7.887998   56.555373  80.802810  120.898222  1358.466600  202.583688
# 2  4.975919  182.086958  87.273632    9.914782  1056.489015  147.098428
# 3  6.304142   58.417235  75.059520   64.167463  1619.924847  307.722320
# 4  1.671733  108.946809  94.910470   14.551922   591.648283   -7.684779
#
#           06         07         08         09  ...         41          42  \
# 0  33.248746 -10.390227  29.262578  43.896138  ...  69.511954  101.547023
# 1  32.494870  19.427739  61.038519  26.967553  ...  92.131989   71.846296
# 2  36.402837  38.900027  30.304666  45.272021  ...  86.164997   59.174616
# 3  34.283344  46.602862  44.859311  11.692485  ...  32.473642    0.674927
# 4  30.980682  39.293311   1.229287  43.643912  ...  37.866648   71.785623
#
#            43          44          45          46          47          48  \
# ...

# %%
#Utilizado o método ffill devido a forte depêndencia temporal da base, necessitando de dados anteriores para preencher os dados faltantes.
x = eda_df.iloc[:, :49].ffill()
y = eda_df['binary_target']

# %store x
# %store y
# Out:
# Stored 'x' (DataFrame)
# Stored 'y' (Series)
